# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="A3tK8MCeZrXPmTjIA87a")
project = rf.workspace("hansika-aredla").project("acne-detection-ehsdp")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolo11n.pt')

# %%
model.train(data='/content/Acne-Detection-1/data.yaml',epochs=100,patience=20)
# Out:
# Ultralytics 8.4.112 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.save('skinyolo11.pt')

# %%
mymodel = YOLO('/content/runs/detect/train-2/weights/best.pt')

# %%
pred=mymodel.predict('/content/Acne-Detection-1/test/images/blackhead_548_jpg.rf.2060638774288946964e5984e4f519f0.jpg')
# Out:
# image 1/1 /content/Acne-Detection-1/test/images/blackhead_548_jpg.rf.2060638774288946964e5984e4f519f0.jpg: 640x640 1 Blackheads, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
pred2=mymodel.predict('/content/Acne-Detection-1/train/images/Papule10_JPG_jpg.rf.79f17b3e5a32763b1cb043e6629d3c8a.jpg')
# Out:
# image 1/1 /content/Acne-Detection-1/train/images/Papule10_JPG_jpg.rf.79f17b3e5a32763b1cb043e6629d3c8a.jpg: 640x640 1 Papules, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred2[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
